# %% [markdown]
# # Tarea: Limpieza de datos
#
# ## Alumno: José de Jesús Hernández Higuera
#
# ### Matrícula: 224470489

# %% [markdown]
# Para comenzar, vamos a darnos una idea de cómo se descargó nuestra base de datos a partir del scraping hecho con scrapy. Dichos datos se encuentran concentrados en un archivo nombrado "nobel_winners.json".

# %%
import pandas as pd

df_nobel = pd.read_json("nobel_winners.json")
df_nobel.head(5)
# Out:
#                                                 link  \
# 0  http://en.wikipedia.org/wiki/Claude_Cohen-Tann...
# 1        http://en.wikipedia.org/wiki/John_Cornforth
# 2  http://en.wikipedia.org/wiki/Frank_Macfarlane_...
# 3        http://en.wikipedia.org/wiki/Barry_Marshall
# 4         http://en.wikipedia.org/wiki/Brian_Schmidt
#
#                           name  year                category    country  \
# 0     Claude Cohen-Tannoudji *  1997                 Physics
# 1             John Cornforth *  1975               Chemistry
# 2  Sir Frank Macfarlane Burnet  1960  Physiology or Medicine  Australia
# 3               Barry Marshall  2005  Physiology or Medicine  Australia
# 4                Brian Schmidt  2011                 Physics  Australia
#
#      born_in                                               text  \
# 0    Algeria            Claude Cohen-Tannoudji *, Physics, 1997
# 1  Australia                  John Cornforth *, Chemistry, 1975
# 2             Sir Frank Macfarlane Burnet , Physiology or Me...
# 3                 Barry Marshall , Physiology or Medicine, 2005
# 4             Brian Schmidt ,  born in the United States , P...
#
#        date_of_birth    date_of_death place_of_birth place_of_death gender
# 0       1 April 1933                     Constantine                  male
# 1   7 September 1917  8 December 2013         Sydney       Brighton   male
# 2   3 September 1899   31 August 1985      Traralgon      Melbourne   male
# 3  30 September 1951                      Kalgoorlie                  male
# 4   24 February 1967                        Missoula                  male

# %% [markdown]
# Una vez visualizado esto, comencemos a hacer cada paso que se requiere de la limpieza de datos:
#
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 1. Verificar que todas las entradas de texto estén codificadas en "unicode"

# %%
df_nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   link            1242 non-null   object
#  1   name            1242 non-null   object
#  2   year            1242 non-null   int64
#  3   category        1242 non-null   object
#  4   country         1242 non-null   object
#  5   born_in         1242 non-null   object
#  6   text            1242 non-null   object
#  7   date_of_birth   1242 non-null   object
#  8   date_of_death   1242 non-null   object
#  9   place_of_birth  1242 non-null   object
#  10  place_of_death  1242 non-null   object
#  11  gender          1242 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 116.6+ KB

# %% [markdown]
# Por defecto, en Python, las cadenas de texto son de tipo Unicode. Sin embargo, para una mayor certeza, podemos asegurar esto desde la carga de la base de datos de la siguiente forma:

# %%
import pandas as pd

df_nobel = pd.read_json("nobel_winners.json", encoding='utf-8') #agregamos el tipo de codificación que necesitamos

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
#
# 2. Remplazar entradas vacías por NaN

# %%
import numpy as np

df_nobel.replace('', np.nan, inplace=True)
df_nobel.head(5)
# Out:
#                                                 link  \
# 0  http://en.wikipedia.org/wiki/Claude_Cohen-Tann...
# 1        http://en.wikipedia.org/wiki/John_Cornforth
# 2  http://en.wikipedia.org/wiki/Frank_Macfarlane_...
# 3        http://en.wikipedia.org/wiki/Barry_Marshall
# 4         http://en.wikipedia.org/wiki/Brian_Schmidt
#
#                           name  year                category    country  \
# 0     Claude Cohen-Tannoudji *  1997                 Physics        NaN
# 1             John Cornforth *  1975               Chemistry        NaN
# 2  Sir Frank Macfarlane Burnet  1960  Physiology or Medicine  Australia
# 3               Barry Marshall  2005  Physiology or Medicine  Australia
# 4                Brian Schmidt  2011                 Physics  Australia
#
#      born_in                                               text  \
# 0    Algeria            Claude Cohen-Tannoudji *, Physics, 1997
# 1  Australia                  John Cornforth *, Chemistry, 1975
# 2        NaN  Sir Frank Macfarlane Burnet , Physiology or Me...
# 3        NaN      Barry Marshall , Physiology or Medicine, 2005
# 4        NaN  Brian Schmidt ,  born in the United States , P...
#
#        date_of_birth    date_of_death place_of_birth place_of_death gender
# 0       1 April 1933              NaN    Constantine            NaN   male
# 1   7 September 1917  8 December 2013         Sydney       Brighton   male
# 2   3 September 1899   31 August 1985      Traralgon      Melbourne   male
# 3  30 September 1951              NaN     Kalgoorlie            NaN   male
# 4   24 February 1967              NaN       Missoula            NaN   male

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 3. Eliminar los asteriscos que aparece en algunos nombres

# %%
#Veamos cuántas entradas tienen asterisco en el nombre
df_nobel[df_nobel['name'].str.contains('\*')]['name']
# Out:
# 0        Claude Cohen-Tannoudji *
# 1                John Cornforth *
# 5           Elizabeth Blackburn *
# 9               Daron Acemoglu **
# 23             Baruj Benacerraf *
#                   ...
# 1233                Walter Kohn *
# 1234         Ardem Patapoutian **
# 1235                Eric Kandel *
# 1236               Albert Camus *
# 1237    Emmanuelle Charpentier **
# Name: name, Length: 169, dtype: object

# %%
#Sustituyamos los asteriscos con un espacio sin caracteres '' en la columna de los nombres
df_nobel['name'] = df_nobel['name'].str.replace('*', '')

#Quitemos los espacios en blanco que haya al final de los nombres
df_nobel['name'] = df_nobel['name'].str.strip()

# %%
#Si los nombres con asteriscos han sido sustituidos, deberíamos obtener un dataframe vacío
df_nobel[df_nobel['name'].str.contains('\*')]
# Out:
# Empty DataFrame
# Columns: [link, name, year, category, country, born_in, text, date_of_birth, date_of_death, place_of_birth, place_of_death, gender]
# Index: []

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 4. Eliminar los individuos repetidos. (Verificar que de veras sea duplicado ya que podría haber ganado 2 veces el nobel en distinto año)

# %%
#Veamos aquellos nombres a los cuales les pertenezcan más de una entrada en la base de datos
dup_name = []
for names, rows in df_nobel.groupby('name'):
    if len(rows) > 1:
        dup_name.append(names) #Creamos una lista con estos nombres
        print(names, len(rows))
# Out:
# Aaron Klug 3
# Abdulrazak Gurnah 2
# Abhijit Banerjee 2
# Alan MacDiarmid 2
# Albert A. Michelson 2
# Albert Camus 2
# Albert Einstein 2
# Albert Lutuli 2
# Albert Schweitzer 2
# Alexei Alexeyevich Abrikosov 2
# Alexei Ekimov 2
# Alfred Werner 2
# Allan M. Cormack 2
# Andre Geim 2
# Andrew Schally 3
# Angus Deaton 2
# Anne L'Huillier 2
# Anthony J. Leggett 2
# Ardem Patapoutian 3
# Arieh Warshel 2
# Arno Penzias 2
# Aziz Sancar 2
# Baruj Benacerraf 2
# Ben Roy Mottelson 2
# Bernard Katz 2
# Bertha von Suttner 2
# Betty Williams 2
# Carl Ferdinand Cori 3
# Charles B. Huggins 2
# Charles J. Pedersen 2
# Charles K. Kao 3
# Christian de Duve 2
# Christopher A. Pissarides 2
# Claude Cohen-Tannoudji 2
# Czesław Miłosz 3
# César Milstein 2
# Daniel Bovet 2
# Daniel C. Tsui 2
# Daniel Kahneman 2
# Daron Acemoglu 3
# David Card 2
# David H. Hubel 2
# David MacMillan 2
# David Trimble 2
# Demis Hassabis 2
# Edmond H. Fischer 2
# Ei-ichi Negishi 2
# Elias Canetti 2
# Elie Wiesel 2
# Elizabeth Blackburn 2
# Emilio Segrè 2
# Emmanuelle Charpentier 3
# Eric Kandel 2
# Ernest Rutherford 2
# Ernst Boris Chain 2
# Esther Duflo 2
# F. Duncan M. Haldane 2
# Felix Bloch 2
# Ferenc Krausz 2
# Franco Modigliani 2
# Fraser Stoddart 2
# Frederick Sanger 2
# Friedrich Hayek 2
# Fritz Albert Lipmann 2
# Gabriel Lippmann 2
# Gao Xingjian 2
# Geoffrey Hinton 2
# George Bernard Shaw 2
# George E. Palade 2
# Georges Charpak 3
# Gerhard Herzberg 2
# Gerty Cori 3
# Giorgos Seferis 2
# Guido Imbens 2
# Gérard Debreu 2
# Günter Blobel 2
# Hans Adolf Krebs 2
# Hans Bethe 2
# Hans G. Dehmelt 2
# Hans von Euler-Chelpin 2
# Har Gobind Khorana 2
# Henry Dunant 2
# Henry Kissinger 2
# Henry Taube 2
# Hermann Hesse 2
# Herta Müller 2
# Ilya Prigogine 2
# Isaac Bashevis Singer 2
# Isidor Isaac Rabi 2
# Ivan Bunin 2
# Ivar Giaever 2
# Ivo Andrić 2
# Jack Steinberger 2
# Jack W. Szostak 3
# James A. Robinson 2
# Jim Peebles 2
# Joachim Frank 2
# John B. Goodenough 2
# John Bardeen 2
# John Cornforth 2
# John M. Kosterlitz 2
# John Macleod 2
# John O'Keefe 2
# John Polanyi 2
# Joseph Brodsky 2
# Joseph Rotblat 2
# Joshua Angrist 2
# Jules A. Hoffmann 2
# K. Barry Sharpless 2
# Karl von Frisch 2
# Katalin Karikó 2
# Kazuo Ishiguro 2
# Konrad Bloch 2
# Konstantin Novoselov 2
# Lars Onsager 2
# Leonid Hurwicz 3
# Leopold Ružička 2
# Linus C. Pauling 2
# Luis Federico Leloir 2
# M. Stanley Whittingham 2
# Mairead Corrigan 2
# Maria Goeppert-Mayer 2
# Maria Ressa 2
# Marie Curie 2
# Marie Skłodowska-Curie 2
# Mario R. Capecchi 2
# Mario Vargas Llosa 2
# Martin Karplus 2
# Maurice Wilkins 2
# Max Born 2
# Max Delbrück 2
# Max Perutz 2
# Menachem Begin 4
# Michael Levitt 4
# Michael Smith 2
# Mother Teresa 2
# Moungi Bawendi 3
# Myron Scholes 2
# Nelly Sachs 2
# Nicolaas Bloembergen 2
# Niels Ryberg Finsen 2
# Nikolaas Tinbergen 2
# Oliver Hart 2
# Oliver Smithies 2
# Osamu Shimomura 2
# Otto Loewi 2
# Otto Stern 2
# Patrick White 2
# Paul J. Crutzen 2
# Peter Grünberg 2
# Pierre Agostini 2
# Polykarp Kusch 2
# Ragnar Granit 2
# Rainer Weiss 2
# Ralph M. Steinman 2
# Renato Dulbecco 2
# Riccardo Giacconi 2
# Richard Kuhn 2
# Rita Levi-Montalcini 2
# Roald Hoffmann 3
# Robert Aumann 2
# Roger Guillemin 2
# Ronald Coase 2
# Ronald Ross 2
# Rudolph A. Marcus 2
# Rudyard Kipling 2
# Salvador Luria 2
# Saul Bellow 2
# Serge Haroche 2
# Severo Ochoa 2
# Seán MacBride 2
# Shimon Peres 3
# Shmuel Yosef Agnon 2
# Shuji Nakamura 2
# Sidney Altman 2
# Simon Johnson 2
# Simon Kuznets 3
# Stefan Hell 2
# Svante Pääbo 3
# Svetlana Alexievich 2
# Sydney Brenner 3
# Syukuro Manabe 2
# T. S. Eliot 2
# Tadeusz Reichstein 2
# Thomas C. Südhof 2
# Tjalling C. Koopmans 2
# Tomas Lindahl 2
# Tsung-Dao Lee 2
# Tu Youyou 2
# V. S. Naipaul 3
# Venkatraman Ramakrishnan 3
# Vladimir Prelog 4
# W. Arthur Lewis 2
# Walter Kohn 2
# Wilhelm Ostwald 2
# Willard S. Boyle 2
# William C. Campbell 2
# William Giauque 2
# William Henry Bragg 2
# William Lawrence Bragg 2
# William Vickrey 2
# Yasser Arafat 2
# Yoichiro Nambu 2
# Yuan T. Lee 2
# Zhores Alferov 2

# %%
#La longitud de la lista equivale al número de nombres que tienen más de dos registros en la base de datos
len(dup_name)
# Out:
# 205

# %%
#Coleccionemos los datos repetidos en un nuevo dataframe
all_dupes = df_nobel[df_nobel.duplicated('name') | df_nobel.duplicated('name', keep='last')]
#Aseguremonos de que las entradas aparecen el mismo número de veces que vimos antes
all_dupes.sort_values(by='name')[['name', 'text', 'born_in', 'country', 'year']]
# Out:
#                    name                                               text  \
# 793          Aaron Klug                      Aaron Klug *, Chemistry, 1982
# 665          Aaron Klug                      Aaron Klug *, Chemistry, 1982
# 529          Aaron Klug  Aaron Klug ,  born in Lithuania , Chemistry, 1982
# 595   Abdulrazak Gurnah              Abdulrazak Gurnah *, Literature, 2021
# 573   Abdulrazak Gurnah  Abdulrazak Gurnah ,  born in Tanzania , Litera...
# ...                 ...                                                ...
# 821      Yoichiro Nambu                    Yoichiro Nambu *, Physics, 2008
# 211         Yuan T. Lee   Yuan T. Lee ,  born in  Taiwan , Chemistry, 1986
# 803         Yuan T. Lee                     Yuan T. Lee *, Chemistry, 1986
# 1206     Zhores Alferov                    Zhores Alferov *, Physics, 2000
# 706      Zhores Alferov  Zhores Alferov ,  born in then Soviet Union, n...
#
#            born_in                  country  year
# 793      Lithuania                      NaN  1982
# 665   South Africa                      NaN  1982
# 529            NaN           United Kingdom  1982
# 595       Tanzania                      NaN  2021
# 573            NaN           United Kingdom  2021
# ...            ...                      ...   ...
# 821          Japan                      NaN  2008
# 211            NaN            United States  1986
# 803          Japan                      NaN  1986
# 1206       Belarus                      NaN  2000
# 706            NaN  Russia and Soviet Union  2000
#
# [436 rows x 5 columns]

# %%
#Si all_dupes contiene todos lo nombres, entonces su longitud también debe de ser de 205
len(all_dupes.groupby('name'))
# Out:
# 205

# %% [markdown]
# *Notemos que tenemos 436 filas dentro de nuestros duplicados, sin embargo, haciendo una búsqueda rápida en internet nos encontramos con que sólo 4 personas han ganado más de un premio Nobel: Marie Curie (1903 y 1911),  Linus C. Pauling (1954 y 1962), John Bardeen (1956 y 1972) y Frederick Sanger (1958 y 1980). Esto es, sólo hay 4 duplicados que son razonables dentro de todos los posibles. En otras palabras, 201 de los 205 nombres no tienen razón para estar dos veces en la base de datos y necesitamos quitar una de sus entradas. Un criterio que parece ser razonable es tomar aquellos registros donde la columna `born_in` está vacía, pues este dato está contenido en `text`, así que se puede recuperar para rellenar los datos faltantes.*

# %%
#Tomemos los nombres del dataframe de las entradas duplicadas y eliminemos aquellas entradas cuyo lugar de nacimiento no está vacío
for i in dup_name:
    df_nobel.drop(df_nobel[(df_nobel.name == i) & ~(df_nobel.born_in.isna())].index, inplace=True)

# %%
#Notemos que la longitud del dataframe original (1242), en efecto, se ha reducido.
len(df_nobel.name)
# Out:
# 1082

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 5. Ordenar por nombre, país y año.

# %%
df_nobel.sort_values(by=['name', 'country', 'year'], inplace=True)
df_nobel.head()
# Out:
#                                                 link               name  year  \
# 893     http://en.wikipedia.org/wiki/14th_Dalai_Lama    14th Dalai Lama  1989
# 279   http://en.wikipedia.org/wiki/A._Michael_Spence  A. Michael Spence  2001
# 1130          http://en.wikipedia.org/wiki/Aage_Bohr          Aage Bohr  1975
# 859   http://en.wikipedia.org/wiki/Aaron_Ciechanover  Aaron Ciechanover  2004
# 529          http://en.wikipedia.org/wiki/Aaron_Klug         Aaron Klug  1982
#
#        category         country born_in  \
# 893       Peace           India     NaN
# 279   Economics   United States     NaN
# 1130    Physics         Denmark     NaN
# 859   Chemistry          Israel     NaN
# 529   Chemistry  United Kingdom     NaN
#
#                                                    text    date_of_birth  \
# 893   14th Dalai Lama ,  born in  Taktser ,  China ,...      6 July 1935
# 279                 A. Michael Spence , Economics, 2001  7 November 1943
# 1130                          Aage Bohr , Physics, 1975     19 June 1922
# 859                 Aaron Ciechanover , Chemistry, 2004   1 October 1947
# 529   Aaron Klug ,  born in Lithuania , Chemistry, 1982   11 August 1926
#
#          date_of_death place_of_birth place_of_death gender
# 893                NaN        Taktser            NaN   male
# 279                NaN      Montclair            NaN   male
# 1130  8 September 2009     Copenhagen     Copenhagen   male
# 859                NaN          Haifa            NaN   male
# 529   20 November 2018          Želva      Cambridge   male

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 6. Rellenar la columna "categoría"

# %%
#Veamos aquellas categorías que estén vacías 
df_nobel[df_nobel['category'].isna()]
# Out:
#                                           link         name  year category  \
# 1211  http://en.wikipedia.org/wiki/Isidor_Rabi  Isidor Rabi     0      NaN
#
#       country born_in                                               text  \
# 1211  Austria     NaN  Isidor Rabi ,  Polish-Jewish   Orthodox , born...
#
#      date_of_birth    date_of_death place_of_birth place_of_death gender
# 1211  29 July 1898  11 January 1988        Rymanów      Manhattan   male

# %% [markdown]
# *Haciendo la revisión en internet, notamos que Isador Rabi ganó el premio Nobel en Física, de modo que se tiene que añadir esto.*

# %%
#Rellenamos la categoría
df_nobel.loc[df_nobel.name == 'Isidor Rabi', 'category'] = 'Physics'

#y, de paso, el año en que ganó el premio
df_nobel.loc[df_nobel.name == 'Isidor Rabi', 'year'] = 1944

# %%
#Revisamos los cambios
df_nobel[df_nobel.name == 'Isidor Rabi']
# Out:
#                                           link         name  year category  \
# 1211  http://en.wikipedia.org/wiki/Isidor_Rabi  Isidor Rabi  1944  Physics
#
#       country born_in                                               text  \
# 1211  Austria     NaN  Isidor Rabi ,  Polish-Jewish   Orthodox , born...
#
#      date_of_birth    date_of_death place_of_birth place_of_death gender
# 1211  29 July 1898  11 January 1988        Rymanów      Manhattan   male

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 7. Rellenar el género de los registros faltantes

# %%
#Veamos aquellas entradas donde el género está vacío
df_nobel[df_nobel['gender'].isna()]
# Out:
#                                                    link  \
# 61    http://en.wikipedia.org/wiki/American_Friends_...
# 522   http://en.wikipedia.org/wiki/Amnesty_Internati...
# 588   http://en.wikipedia.org/wiki/Centre_for_Civil_...
# 475   http://en.wikipedia.org/wiki/Friends_Service_C...
# 1189  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 716     http://en.wikipedia.org/wiki/Memorial_(society)
# 1094  http://en.wikipedia.org/wiki/M%C3%A9decins_San...
# 826         http://en.wikipedia.org/wiki/Nihon_Hidankyo
# 790   http://en.wikipedia.org/wiki/Organisation_for_...
# 1174  http://en.wikipedia.org/wiki/Pugwash_Conferenc...
# 597   http://en.wikipedia.org/wiki/Tunisian_National...
#
#                                                    name  year category  \
# 61    American Friends Service Committee  (The Quakers)  1947    Peace
# 522                               Amnesty International  1977    Peace
# 588                          Centre for Civil Liberties  2022    Peace
# 475                             Friends Service Council  1947    Peace
# 1189                    Institut de Droit International  1904    Peace
# 716                                            Memorial  2022    Peace
# 1094                           Médecins Sans Frontières  1999    Peace
# 826                                      Nihon Hidankyo  2024    Peace
# 790   Organisation for the Prohibition of Chemical W...  2013    Peace
# 1174   Pugwash Conferences on Science and World Affairs  1995    Peace
# 597                  Tunisian National Dialogue Quartet  2015    Peace
#
#                       country born_in  \
# 61              United States     NaN
# 522            United Kingdom     NaN
# 588                   Ukraine     NaN
# 475            United Kingdom     NaN
# 1189                  Belgium     NaN
# 716   Russia and Soviet Union     NaN
# 1094                   France     NaN
# 826                       NaN   Japan
# 790               Netherlands     NaN
# 1174                   Canada     NaN
# 597                   Tunisia     NaN
#
#                                                    text date_of_birth  \
# 61    American Friends Service Committee  (The Quake...           NaN
# 522                 Amnesty International , Peace, 1977           NaN
# 588            Centre for Civil Liberties , Peace, 2022           NaN
# 475               Friends Service Council , Peace, 1947           NaN
# 1189      Institut de Droit International , Peace, 1904           NaN
# 716                              Memorial , Peace, 2022           NaN
# 1094             Médecins Sans Frontières , Peace, 1999           NaN
# 826                       Nihon Hidankyo *, Peace, 2024           NaN
# 790   Organisation for the Prohibition of Chemical W...           NaN
# 1174  Pugwash Conferences on Science and World Affai...           NaN
# 597    Tunisian National Dialogue Quartet , Peace, 2015           NaN
#
#      date_of_death place_of_birth place_of_death gender
# 61             NaN            NaN            NaN    NaN
# 522            NaN            NaN            NaN    NaN
# 588            NaN            NaN            NaN    NaN
# 475            NaN            NaN            NaN    NaN
# 1189           NaN            NaN            NaN    NaN
# 716            NaN            NaN            NaN    NaN
# 1094           NaN            NaN            NaN    NaN
# 826            NaN            NaN            NaN    NaN
# 790            NaN            NaN            NaN    NaN
# 1174           NaN            NaN            NaN    NaN
# 597            NaN            NaN            NaN    NaN

# %% [markdown]
# *Todas las entradas en este apartado donde el género está vacío pertenecen a organizaciones o instituciones, por lo tanto, no se les puede dar un género y, más adelante, serán eliminadas en el paso 9.*

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 8. Convertir los registros de fecha de nacimiento y fecha de muerte en NumPy datetime64

# %%
#Comencemos por la fecha de nacimiento
df_nobel['date_of_birth'] = pd.to_datetime(df_nobel.date_of_birth, errors='raise')

#Luego continuamos con la fecha de defunción
df_nobel['date_of_death'] = pd.to_datetime(df_nobel.date_of_death, errors='coerce').dt.date

#Finalmente, para evitar dejar vacías las fechas de fallecimiento, pongamos que hay personas que siguen vivas
df_nobel.loc[df_nobel['date_of_death'].isna(), 'date_of_death'] = 'alive'

# %%
#Comprobemos que se han guardado los cambios
df_nobel[['name', 'date_of_birth', 'date_of_death']]
# Out:
#                      name date_of_birth date_of_death
# 893       14th Dalai Lama    1935-07-06         alive
# 279     A. Michael Spence    1943-11-07         alive
# 1130            Aage Bohr    1922-06-19    2009-09-08
# 859     Aaron Ciechanover    1947-10-01         alive
# 529            Aaron Klug    1926-08-11    2018-11-20
# ...                   ...           ...           ...
# 1090         Yves Chauvin    1930-10-10    2015-01-28
# 706        Zhores Alferov    1930-03-15    2019-03-01
# 606         Élie Ducommun    1833-02-19    1906-12-07
# 684      Élie Metchnikoff    1845-05-03    1916-07-02
# 1142  Óscar Arias Sánchez    1941-09-13         alive
#
# [1082 rows x 3 columns]

# %% [markdown]
# <div style="background-color: #FFB400; border-left: 10px solid #007acc; padding: 10px; border-radius: 5px; margin: 10px 0;">
# 9. Eliminar premios que no fueron dados a personas

# %%
#Como vimos antes, aquellos premios que no fueron otorgados a personas no tienen género, entonces pordemos eliminarlos
df_nobel.drop(df_nobel[df_nobel.gender.isna()].index, inplace=True)

#Confirmemos que no hay más entradas donde el género no aparezca
df_nobel[df_nobel['gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [link, name, year, category, country, born_in, text, date_of_birth, date_of_death, place_of_birth, place_of_death, gender]
# Index: []

# %%
#Finalmente, la base de datos tiene la forma
df_nobel_clean = df_nobel
df_nobel_clean #Las entradas pasan de ser 1082 a 1071
# Out:
#                                                    link                 name  \
# 893        http://en.wikipedia.org/wiki/14th_Dalai_Lama      14th Dalai Lama
# 279      http://en.wikipedia.org/wiki/A._Michael_Spence    A. Michael Spence
# 1130             http://en.wikipedia.org/wiki/Aage_Bohr            Aage Bohr
# 859      http://en.wikipedia.org/wiki/Aaron_Ciechanover    Aaron Ciechanover
# 529             http://en.wikipedia.org/wiki/Aaron_Klug           Aaron Klug
# ...                                                 ...                  ...
# 1090          http://en.wikipedia.org/wiki/Yves_Chauvin         Yves Chauvin
# 706         http://en.wikipedia.org/wiki/Zhores_Alferov       Zhores Alferov
# 606     http://en.wikipedia.org/wiki/%C3%89lie_Ducommun        Élie Ducommun
# 684   http://en.wikipedia.org/wiki/%C3%89lie_Metchni...     Élie Metchnikoff
# 1142      http://en.wikipedia.org/wiki/%C3%93scar_Arias  Óscar Arias Sánchez
#
#       year                category                  country born_in  \
# 893   1989                   Peace                    India     NaN
# 279   2001               Economics            United States     NaN
# 1130  1975                 Physics                  Denmark     NaN
# 859   2004               Chemistry                   Israel     NaN
# 529   1982               Chemistry           United Kingdom     NaN
# ...    ...                     ...                      ...     ...
# 1090  2005               Chemistry                   France     NaN
# 706   2000                 Physics  Russia and Soviet Union     NaN
# 606   1902                   Peace              Switzerland     NaN
# 684   1908  Physiology or Medicine  Russia and Soviet Union     NaN
# 1142  1987                   Peace               Costa Rica     NaN
#
#                                                    text date_of_birth  \
# 893   14th Dalai Lama ,  born in  Taktser ,  China ,...    1935-07-06
# 279                 A. Michael Spence , Economics, 2001    1943-11-07
# 1130                          Aage Bohr , Physics, 1975    1922-06-19
# 859                 Aaron Ciechanover , Chemistry, 2004    1947-10-01
# 529   Aaron Klug ,  born in Lithuania , Chemistry, 1982    1926-08-11
# ...                                                 ...           ...
# 1090                     Yves Chauvin , Chemistry, 2005    1930-10-10
# 706   Zhores Alferov ,  born in then Soviet Union, n...    1930-03-15
# 606                         Élie Ducommun , Peace, 1902    1833-02-19
# 684   Élie Metchnikoff ,  born in now Ukraine , Phys...    1845-05-03
# 1142                  Óscar Arias Sánchez , Peace, 1987    1941-09-13
#
#      date_of_death place_of_birth    place_of_death gender
# 893          alive        Taktser               NaN   male
# 279          alive      Montclair               NaN   male
# 1130    2009-09-08     Copenhagen        Copenhagen   male
# 859          alive          Haifa               NaN   male
# 529     2018-11-20          Želva         Cambridge   male
# ...            ...            ...               ...    ...
# 1090    2015-01-28          Menen             Tours   male
# 706     2019-03-01        Vitebsk  Saint Petersburg   male
# 606     1906-12-07         Geneva              Bern   male
# 684     1916-07-02       Ivanivka             Paris   male
# 1142         alive        Heredia               NaN   male
#
# [1071 rows x 12 columns]

# %%
#Guardemos la base de datos limpia en un nuevo archivo
df_nobel_clean.to_json('clean_nobel_winners.json', orient='records', lines=True)
